# %%
import rosbag

bag = rosbag.Bag('/home/naosi/participantbags/P105.bag')
for topic, msg, t in bag.read_messages(topics=['/space_invaders/game/game_condition',
                                               '/space_invaders/game/game_mode',
                                               '/space_invaders/game/nao_action']):
    print(topic, msg.data, t)
    #print(t)
bag.close()
# Out:
# /space_invaders/game/game_mode 0 1657572209647034566
# /space_invaders/game/game_condition Z 1657572209647202615
# /space_invaders/game/nao_action frame_2382 wake_start 1657572325092537902
# /space_invaders/game/nao_action frame_2382 wake_end 1657572326541925737
# /space_invaders/game/nao_action frame_2382 introduction_start 1657572326541932825
# /space_invaders/game/nao_action frame_2382 wave_start 1657572326636693231
# /space_invaders/game/nao_action frame_2382 wave_stop 1657572334998347030
# /space_invaders/game/nao_action frame_2382 introduction_end 1657572340525196648
# /space_invaders/game/nao_action frame_2382 wake_start 1657572373212949170
# /space_invaders/game/nao_action frame_2382 wake_end 1657572374785198689
# /space_invaders/game/game_condition D 1657572379090465306
# /space_invaders/game/game_mode 3 1657572379090519633
# /space_invaders/game/nao_action frame_0 idle_3 1657572379095690410
# /space_invaders/game/nao_action frame_0 i_play 1657572379101348478
# ...
